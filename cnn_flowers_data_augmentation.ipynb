# %% [markdown]
# <a href="https://colab.research.google.com/github/mdr356/cnn-flowers-data-augmentation/blob/master/cnn_flowers_data_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

import glob
import shutil


# download dataset
_URL = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

zip_file = tf.keras.utils.get_file(origin=_URL,
                                   fname="flower_photos.tgz",
                                   extract=True)

base_dir = os.path.join(os.path.dirname(zip_file), 'flower_photos')

# labels (output) are 5 classes
classes = ['roses', 'daisy', 'dandelion', 'sunflowers', 'tulips']

for cl in classes:
  img_path = os.path.join(base_dir, cl)
  images = glob.glob(img_path + '/*.jpg')
  print("{}: {} Images".format(cl, len(images)))
  train, val = images[:round(len(images)*0.8)], images[round(len(images)*0.8):]

  for t in train:
    if not os.path.exists(os.path.join(base_dir, 'train', cl)):
      os.makedirs(os.path.join(base_dir, 'train', cl))
    shutil.move(t, os.path.join(base_dir, 'train', cl))

  for v in val:
    if not os.path.exists(os.path.join(base_dir, 'val', cl)):
      os.makedirs(os.path.join(base_dir, 'val', cl))
    shutil.move(v, os.path.join(base_dir, 'val', cl))
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228813984/228813984 ━━━━━━━━━━━━━━━━━━━━ 10s 0us/step
# roses: 641 Images
# daisy: 633 Images
# dandelion: 898 Images
# sunflowers: 699 Images
# tulips: 799 Images

# %%
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')

#data augmentation
image_gen = ImageDataGenerator(rescale=1./255,
                               horizontal_flip=True, # randomly flip the image
                               rotation_range=45, # rotate the image to 45
                               zoom_range=0.5, #randomly zoom
                               width_shift_range=0.15, # shift the image
                               height_shift_range=0.15)

val_gen_val = ImageDataGenerator(rescale=1./255)

IMG_SHAPE = 150
batch_size = 100
image_data_gen = image_gen.flow_from_directory(directory=train_dir,
                                               batch_size=batch_size,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE,IMG_SHAPE),
                                               class_mode='categorical')

val_data_gen_val = val_gen_val.flow_from_directory(directory=val_dir,
                                               shuffle=False,
                                               target_size=(IMG_SHAPE,IMG_SHAPE),
                                               class_mode='categorical')

# create model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(IMG_SHAPE, IMG_SHAPE, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(5, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# train the model
history = model.fit(image_data_gen,
                    epochs=100,
                    steps_per_epoch=len(image_data_gen)//batch_size,
                    validation_data=val_data_gen_val,
                    validation_steps=len(val_data_gen_val)//batch_size,
                    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=2)])

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.show()
# Out:
# Found 2935 images belonging to 5 classes.
# Found 735 images belonging to 5 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)                    │ (None, 148, 148, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 74, 74, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 72, 72, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 36, 36, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 34, 34, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 17, 17, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 17, 17, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 18496)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 512)                 │       9,470,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 5)                   │           2,565 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,496,613 (36.23 MB)
#  Trainable params: 9,496,613 (36.23 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 25s 594ms/step - accuracy: 0.2834 - loss: 1.6761 - val_accuracy: 0.4857 - val_loss: 1.2172
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 489ms/step - accuracy: 0.5147 - loss: 1.1732 - val_accuracy: 0.5850 - val_loss: 1.0635
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 487ms/step - accuracy: 0.6018 - loss: 1.0265 - val_accuracy: 0.6027 - val_loss: 1.0010
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 495ms/step - accuracy: 0.6469 - loss: 0.9569 - val_accuracy: 0.6381 - val_loss: 0.9119
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 503ms/step - accuracy: 0.6371 - loss: 0.9115 - val_accuracy: 0.6585 - val_loss: 0.9111
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 491ms/step - accuracy: 0.6670 - loss: 0.8785 - val_accuracy: 0.6422 - val_loss: 0.8987
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 494ms/step - accuracy: 0.6970 - loss: 0.8349 - val_accuracy: 0.7020 - val_loss: 0.7917
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 497ms/step - accuracy: 0.6814 - loss: 0.8296 - val_accuracy: 0.6803 - val_loss: 0.7832
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 485ms/step - accuracy: 0.6907 - loss: 0.8035 - val_accuracy: 0.7048 - val_loss: 0.7822
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 492ms/step - accuracy: 0.6875 - loss: 0.7996 - val_accuracy: 0.6680 - val_loss: 0.8133
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 505ms/step - accuracy: 0.6854 - loss: 0.8057 - val_accuracy: 0.7211 - val_loss: 0.7535
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 489ms/step - accuracy: 0.6858 - loss: 0.7926 - val_accuracy: 0.7088 - val_loss: 0.7382
# Epoch 13/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 491ms/step - accuracy: 0.7265 - loss: 0.7374 - val_accuracy: 0.7265 - val_loss: 0.7248
# Epoch 14/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 496ms/step - accuracy: 0.7210 - loss: 0.7168 - val_accuracy: 0.6939 - val_loss: 0.7411
# Epoch 15/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 488ms/step - accuracy: 0.7081 - loss: 0.7348 - val_accuracy: 0.7306 - val_loss: 0.6858
# Epoch 16/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 492ms/step - accuracy: 0.7268 - loss: 0.6973 - val_accuracy: 0.7170 - val_loss: 0.7068
# Epoch 17/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 487ms/step - accuracy: 0.7221 - loss: 0.6926 - val_accuracy: 0.7252 - val_loss: 0.7006
# Epoch 18/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 486ms/step - accuracy: 0.7453 - loss: 0.6627 - val_accuracy: 0.7619 - val_loss: 0.6606
# Epoch 19/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 492ms/step - accuracy: 0.7167 - loss: 0.6987 - val_accuracy: 0.7252 - val_loss: 0.7066
# Epoch 20/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 502ms/step - accuracy: 0.7462 - loss: 0.6440 - val_accuracy: 0.7442 - val_loss: 0.6611
# Epoch 21/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 482ms/step - accuracy: 0.7449 - loss: 0.6656 - val_accuracy: 0.7293 - val_loss: 0.7367
# Epoch 22/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 485ms/step - accuracy: 0.7313 - loss: 0.6545 - val_accuracy: 0.7075 - val_loss: 0.7187

# %% [markdown]
# **Adding more dropout layer. will add one after each layer about 0.1%**
#
# sparse_categorical_crossentropy (scce) produces a category index of the most likely matching category. Decided to use that instead of categorial class mode. If you change the class mode in ImageDataGenerator than the loss paramater also needs to change.

# %%
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')

#data augmentation
image_gen = ImageDataGenerator(rescale=1./255,
                               horizontal_flip=True, # randomly flip the image
                               rotation_range=45, # rotate the image to 45
                               zoom_range=0.5, #randomly zoom
                               width_shift_range=0.15, # shift the image
                               height_shift_range=0.15)

val_gen_val = ImageDataGenerator(rescale=1./255)

IMG_SHAPE = 150
batch_size = 100
image_data_gen = image_gen.flow_from_directory(directory=train_dir,
                                               batch_size=batch_size,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE,IMG_SHAPE),
                                               class_mode='sparse')

val_data_gen_val = val_gen_val.flow_from_directory(directory=val_dir,
                                               shuffle=False,
                                               target_size=(IMG_SHAPE,IMG_SHAPE),
                                               class_mode='sparse')

# create model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(IMG_SHAPE, IMG_SHAPE, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.1),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.1),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.1),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(5, activation='softmax')
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()
EPOCH = 20
# train the model
history = model.fit(image_data_gen,
                    epochs=EPOCH,
                    steps_per_epoch=len(image_data_gen)//batch_size,
                    validation_data=val_data_gen_val,
                    validation_steps=len(val_data_gen_val)//batch_size)
                    #callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=2)])

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')
plt.show()
# Out:
# Found 2935 images belonging to 5 classes.
# Found 735 images belonging to 5 classes.
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_21 (Conv2D)                   │ (None, 148, 148, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_21 (MaxPooling2D)      │ (None, 74, 74, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_26 (Dropout)                 │ (None, 74, 74, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 72, 72, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_22 (MaxPooling2D)      │ (None, 36, 36, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_27 (Dropout)                 │ (None, 36, 36, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 34, 34, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_23 (MaxPooling2D)      │ (None, 17, 17, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_28 (Dropout)                 │ (None, 17, 17, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_7 (Flatten)                  │ (None, 18496)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 512)                 │       9,470,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 5)                   │           2,565 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,496,613 (36.23 MB)
#  Trainable params: 9,496,613 (36.23 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 23s 513ms/step - accuracy: 0.2517 - loss: 2.1256 - val_accuracy: 0.3905 - val_loss: 1.3866
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 18s 473ms/step - accuracy: 0.4434 - loss: 1.2967 - val_accuracy: 0.5265 - val_loss: 1.1977
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 18s 475ms/step - accuracy: 0.5423 - loss: 1.1152 - val_accuracy: 0.5429 - val_loss: 1.1069
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 18s 474ms/step - accuracy: 0.5516 - loss: 1.0958 - val_accuracy: 0.5415 - val_loss: 1.1039
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 18s 479ms/step - accuracy: 0.6035 - loss: 1.0189 - val_accuracy: 0.5524 - val_loss: 1.1233
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 490ms/step - accuracy: 0.5971 - loss: 1.0138 - val_accuracy: 0.5728 - val_loss: 1.0608
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 495ms/step - accuracy: 0.6184 - loss: 0.9727 - val_accuracy: 0.6245 - val_loss: 0.9695
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 18s 476ms/step - accuracy: 0.6408 - loss: 0.9146 - val_accuracy: 0.6190 - val_loss: 0.9574
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 18s 474ms/step - accuracy: 0.6548 - loss: 0.8869 - val_accuracy: 0.6395 - val_loss: 0.9204
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 485ms/step - accuracy: 0.6519 - loss: 0.9000 - val_accuracy: 0.6367 - val_loss: 0.9108
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 18s 472ms/step - accuracy: 0.6659 - loss: 0.8628 - val_accuracy: 0.6422 - val_loss: 0.9081
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 18s 488ms/step - accuracy: 0.6648 - loss: 0.8598 - val_accuracy: 0.6054 - val_loss: 0.9597
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 494ms/step - accuracy: 0.6717 - loss: 0.8619 - val_accuracy: 0.6340 - val_loss: 0.9444
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 18s 475ms/step - accuracy: 0.6698 - loss: 0.8501 - val_accuracy: 0.6599 - val_loss: 0.8594
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 494ms/step - accuracy: 0.6919 - loss: 0.7829 - val_accuracy: 0.6585 - val_loss: 0.8401
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 478ms/step - accuracy: 0.6900 - loss: 0.7901 - val_accuracy: 0.6667 - val_loss: 0.8190
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 481ms/step - accuracy: 0.6855 - loss: 0.7923 - val_accuracy: 0.6871 - val_loss: 0.7889
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 18s 477ms/step - accuracy: 0.7036 - loss: 0.7907 - val_accuracy: 0.6735 - val_loss: 0.8285
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 19s 494ms/step - accuracy: 0.7096 - loss: 0.7642 - val_accuracy: 0.7034 - val_loss: 0.7593
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 18s 478ms/step - accuracy: 0.7054 - loss: 0.7501 - val_accuracy: 0.6966 - val_loss: 0.7927

# %% [markdown]
# **Transfer Learning**

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import tf_keras
import glob
import shutil
import tensorflow_hub as hub

# download dataset
_URL = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

zip_file = tf.keras.utils.get_file(origin=_URL,
                                   fname="flower_photos.tgz",
                                   extract=True)

base_dir = os.path.join(os.path.dirname(zip_file), 'flower_photos')

# labels (output) are 5 classes
classes = ['roses', 'daisy', 'dandelion', 'sunflowers', 'tulips']

for cl in classes:
  img_path = os.path.join(base_dir, cl)
  images = glob.glob(img_path + '/*.jpg')
  print("{}: {} Images".format(cl, len(images)))
  train, val = images[:round(len(images)*0.8)], images[round(len(images)*0.8):]

  for t in train:
    if not os.path.exists(os.path.join(base_dir, 'train', cl)):
      os.makedirs(os.path.join(base_dir, 'train', cl))
    shutil.move(t, os.path.join(base_dir, 'train', cl))

  for v in val:
    if not os.path.exists(os.path.join(base_dir, 'val', cl)):
      os.makedirs(os.path.join(base_dir, 'val', cl))
    shutil.move(v, os.path.join(base_dir, 'val', cl))

train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')

BATCH_SIZE = 100
IMG_SHAPE = 224
EPOCH = 50
train_image_gen = ImageDataGenerator(rescale=1./255,
                               rotation_range=45,
                               zoom_range=0.5,
                               horizontal_flip=True,
                               width_shift_range=0.15,
                               height_shift_range=0.15)


val_gen_val = ImageDataGenerator(rescale=1./255)

train_data = train_image_gen.flow_from_directory(directory=train_dir,
                                               batch_size=BATCH_SIZE,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE,IMG_SHAPE),
                                               class_mode='sparse')

val_data = val_gen_val.flow_from_directory(directory=val_dir,
                                               shuffle=False,
                                               target_size=(IMG_SHAPE,IMG_SHAPE),
                                               class_mode='sparse')

# create model
CLASSIFICATION_URL = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/2"

feature_extractor_layer = hub.KerasLayer(CLASSIFICATION_URL, input_shape=(IMG_SHAPE, IMG_SHAPE, 3))
feature_extractor_layer.trainable = False

model = tf_keras.models.Sequential([
    feature_extractor_layer,
    tf_keras.layers.Dense(5, activation='softmax')
])

#compile model
model.compile(optimizer='Adam',
              loss=tf_keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()

history = model.fit(train_data,
                    epochs=EPOCH,
                    steps_per_epoch=len(train_data),
                    validation_data=val_data,
                    validation_steps=len(val_data),
                    callbacks=[tf_keras.callbacks.EarlyStopping(monitor='loss', patience=2)])

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(range(len(history.history['accuracy'])), history.history['accuracy'], label='Learning Accuracy') # Change range(EPOCH) to dynamically match the length of the accuracy data
plt.plot(range(len(history.history['val_accuracy'])), history.history['val_accuracy'], label='Validation Accuracy') # Change range(EPOCH) to dynamically match the length of the val_accuracy data
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1,2,2)
plt.plot(range(len(history.history['loss'])), history.history['loss'], label='Learning Loss') # Change range(EPOCH) to dynamically match the length of the loss data
plt.plot(range(len(history.history['val_loss'])), history.history['val_loss'], label='Validation Loss') # Change range(EPOCH) to dynamically match the length of the val_loss data
plt.legend(loc='lower right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Found 2935 images belonging to 5 classes.
# Found 735 images belonging to 5 classes.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer_5 (KerasLayer)  (None, 1001)              3540265
#
#  dense_5 (Dense)             (None, 5)                 5010
#
# =================================================================
# Total params: 3545275 (13.52 MB)
# Trainable params: 5010 (19.57 KB)
# Non-trainable params: 3540265 (13.51 MB)
# _________________________________________________________________
# Epoch 1/50
# 30/30 [==============================] - 36s 1s/step - loss: 1.2270 - accuracy: 0.5775 - val_loss: 0.5955 - val_accuracy: 0.7905
# Epoch 2/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.5853 - accuracy: 0.7830 - val_loss: 0.4588 - val_accuracy: 0.8259
# Epoch 3/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.4914 - accuracy: 0.8245 - val_loss: 0.4184 - val_accuracy: 0.8503
# Epoch 4/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.4545 - accuracy: 0.8388 - val_loss: 0.3838 - val_accuracy: 0.8599
# Epoch 5/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.4288 - accuracy: 0.8446 - val_loss: 0.3667 - val_accuracy: 0.8694
# Epoch 6/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.3879 - accuracy: 0.8654 - val_loss: 0.3497 - val_accuracy: 0.8748
# Epoch 7/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.3712 - accuracy: 0.8630 - val_loss: 0.3415 - val_accuracy: 0.8803
# Epoch 8/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.3656 - accuracy: 0.8753 - val_loss: 0.3417 - val_accuracy: 0.8803
# Epoch 9/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.3604 - accuracy: 0.8746 - val_loss: 0.3369 - val_accuracy: 0.8776
# Epoch 10/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.3749 - accuracy: 0.8651 - val_loss: 0.3307 - val_accuracy: 0.8789
# Epoch 11/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.3474 - accuracy: 0.8770 - val_loss: 0.3390 - val_accuracy: 0.8748
# Epoch 12/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.3437 - accuracy: 0.8753 - val_loss: 0.3223 - val_accuracy: 0.8857
# Epoch 13/50
# 30/30 [==============================] - 33s 1s/step - loss: 0.3302 - accuracy: 0.8818 - val_loss: 0.3239 - val_accuracy: 0.8844
# Epoch 14/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.3352 - accuracy: 0.8814 - val_loss: 0.3295 - val_accuracy: 0.8830
# Epoch 15/50
# 30/30 [==============================] - 32s 1s/step - loss: 0.3305 - accuracy: 0.8743 - val_loss: 0.3287 - val_accuracy: 0.8884
